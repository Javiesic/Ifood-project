# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('../data/ml_project1_data.csv')
# Calcular el gasto total en iFood
data['Total_Spent'] = (data['MntWines'] + data['MntFruits'] + data['MntMeatProducts'] + data['MntFishProducts'] + data['MntSweetProducts'] + data['MntGoldProds'])
# Seleccionar las columnas relevantes
income_spent = data[['Income', 'Total_Spent']]

Q1 = income_spent.quantile(0.25)
Q3 = income_spent.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

Datos_filtrados = income_spent[~((income_spent < lower_bound) | (income_spent > upper_bound)).any(axis=1)]

plt.figure(figsize=(10, 6))
plt.scatter(Datos_filtrados['Income'], Datos_filtrados['Total_Spent'], alpha=0.5)
plt.title('Relación entre Ingresos Anuales y Gasto Total en iFood (Sin Outliers)')
plt.xlabel('Ingresos Anuales')
plt.ylabel('Gasto Total en iFood')
plt.grid(True)
plt.show()

# %% [markdown]
# Visualizando la gráfica, quitando los outliers que hacen que se represente datos fuera de lo normal, se observa una correlación positiva entre los ingresos anuales y la cantidad de dinero que gastan en iFood, es decir, cuanto mas ingresos mas dinero gastado en iFood. Por lo tanto, interpretando la gráfica si que existe una relación
